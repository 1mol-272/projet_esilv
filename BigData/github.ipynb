# %% [markdown]
# git --version
#
# **git初始化**
#
# git init
#
# **登陆设置**
#
# git config --global user.name "tengzhezhang0-sketch"
# git config --global user.email "tengzhezhang0@gmail.com"
#
# **记得设置.gitignore**
#
# **查看状态**
#
# git status
#
# **把所有文件加入暂存区**
# git add .
#
# **提交**
# git commit -m ""
#
# **在本地项目中关联远程仓库**
#
# git remote add origin https://github.com/
# tengzhezhang0-sketch/projet_esilv_bigdata.git
#
# **推到远程**
#
# git push -u origin main \
# -u 帮你记住上下游关系
